# %%
# Cell 1: Setup Python Path for Local Imports
import sys
import os

# Add the project root to sys.path
project_path = os.path.abspath(".")
if project_path not in sys.path:
    sys.path.insert(0, project_path)

print("✅ Project path added for local imports")
# Out:
# ✅ Project path added for local imports

# %%
# Cell 2: Import Modules
import sqlite3
import pandas as pd
import time
import webbrowser

from jobhunter import config
from jobhunter.extract import extract
from jobhunter.dataTransformer import DataTransformer
from jobhunter.FileHandler import FileHandler
from jobhunter.load import load
from jobhunter.SQLiteHandler import (
    save_text_to_db,
    update_similarity_in_db,
    fetch_resumes_from_db,
)

print("✅ Modules imported")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 7
#       4 import time
#       5 import webbrowser
# ----> 7 from jobhunter import config
#       8 from jobhunter.extract import extract
#       9 from jobhunter.dataTransformer import DataTransformer
#
# ModuleNotFoundError: No module named 'jobhunter'

# %%
pip install jobhunter
# Out:
# Collecting jobhunter
#   Downloading JobHunter-0.0.2-py3-none-any.whl.metadata (896 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\anaconda3\lib\site-packages (from jobhunter) (4.12.3)
# Requirement already satisfied: black in c:\users\asus\anaconda3\lib\site-packages (from jobhunter) (24.8.0)
# Collecting chromedriver-autoinstaller (from jobhunter)
#   Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl.metadata (2.1 kB)
# Collecting gspread (from jobhunter)
#   Downloading gspread-6.2.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: lxml in c:\users\asus\anaconda3\lib\site-packages (from jobhunter) (5.2.1)
# Collecting oauth2client (from jobhunter)
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pydantic[email] in c:\users\asus\anaconda3\lib\site-packages (from jobhunter) (2.8.2)
# Requirement already satisfied: python-dotenv in c:\users\asus\anaconda3\lib\site-packages (from jobhunter) (0.21.0)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from jobhunter) (2.32.3)
# Collecting selenium (from jobhunter)
#   Downloading selenium-4.34.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\anaconda3\lib\site-packages (from beautifulsoup4->jobhunter) (2.5)
# Requirement already satisfied: click>=8.0.0 in c:\users\asus\anaconda3\lib\site-packages (from black->jobhunter) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\asus\anaconda3\lib\site-packages (from black->jobhunter) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\asus\anaconda3\lib\site-packages (from black->jobhunter) (24.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\asus\anaconda3\lib\site-packages (from black->jobhunter) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\asus\anaconda3\lib\site-packages (from black->jobhunter) (3.10.0)
# Collecting google-auth>=1.12.0 (from gspread->jobhunter)
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-oauthlib>=0.4.1 (from gspread->jobhunter)
#   Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting httplib2>=0.9.1 (from oauth2client->jobhunter)
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\asus\anaconda3\lib\site-packages (from oauth2client->jobhunter) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\asus\anaconda3\lib\site-packages (from oauth2client->jobhunter) (0.2.8)
# Collecting rsa>=3.1.4 (from oauth2client->jobhunter)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: six>=1.6.1 in c:\users\asus\anaconda3\lib\site-packages (from oauth2client->jobhunter) (1.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic[email]->jobhunter) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic[email]->jobhunter) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic[email]->jobhunter) (4.11.0)
# Collecting email-validator>=2.0.0 (from pydantic[email]->jobhunter)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests->jobhunter) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests->jobhunter) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests->jobhunter) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests->jobhunter) (2025.4.26)
# Collecting urllib3<3,>=1.21.1 (from requests->jobhunter)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting trio~=0.30.0 (from selenium->jobhunter)
#   Using cached trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium->jobhunter)
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting certifi>=2017.4.17 (from requests->jobhunter)
#   Downloading certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic[email]->jobhunter)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\asus\anaconda3\lib\site-packages (from selenium->jobhunter) (1.8.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from click>=8.0.0->black->jobhunter) (0.4.6)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]->jobhunter)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread->jobhunter) (5.3.3)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib>=0.4.1->gspread->jobhunter)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\asus\anaconda3\lib\site-packages (from httplib2>=0.9.1->oauth2client->jobhunter) (3.1.2)
# Collecting attrs>=23.2.0 (from trio~=0.30.0->selenium->jobhunter)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sortedcontainers in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.30.0->selenium->jobhunter) (2.4.0)
# Collecting outcome (from trio~=0.30.0->selenium->jobhunter)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.30.0->selenium->jobhunter) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.30.0->selenium->jobhunter) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium->jobhunter)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\asus\anaconda3\lib\site-packages (from urllib3[socks]~=2.5.0->selenium->jobhunter) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium->jobhunter) (2.21)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread->jobhunter)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\asus\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium->jobhunter) (0.14.0)
# Downloading JobHunter-0.0.2-py3-none-any.whl (19 kB)
# Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Downloading gspread-6.2.1-py3-none-any.whl (59 kB)
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Downloading selenium-4.34.2-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.4 MB 304.8 kB/s eta 0:00:30
#    -- ------------------------------------- 0.5/9.4 MB 304.8 kB/s eta 0:00:30
#    -- ------------------------------------- 0.5/9.4 MB 304.8 kB/s eta 0:00:30
#    --- ------------------------------------ 0.8/9.4 MB 342.2 kB/s eta 0:00:26
#    --- ------------------------------------ 0.8/9.4 MB 342.2 kB/s eta 0:00:26
#    --- ------------------------------------ 0.8/9.4 MB 342.2 kB/s eta 0:00:26
#    --- ------------------------------------ 0.8/9.4 MB 342.2 kB/s eta 0:00:26
#    --- ------------------------------------ 0.8/9.4 MB 342.2 kB/s eta 0:00:26
#    ---- ----------------------------------- 1.0/9.4 MB 287.5 kB/s eta 0:00:30
#    ---- ----------------------------------- 1.0/9.4 MB 287.5 kB/s eta 0:00:30
#    ---- ----------------------------------- 1.0/9.4 MB 287.5 kB/s eta 0:00:30
#    ---- ----------------------------------- 1.0/9.4 MB 287.5 kB/s eta 0:00:30
#    ----- ---------------------------------- 1.3/9.4 MB 290.5 kB/s eta 0:00:28
#    ----- ---------------------------------- 1.3/9.4 MB 290.5 kB/s eta 0:00:28
#    ----- ---------------------------------- 1.3/9.4 MB 290.5 kB/s eta 0:00:28
#    ----- ---------------------------------- 1.3/9.4 MB 290.5 kB/s eta 0:00:28
#    ------ --------------------------------- 1.6/9.4 MB 300.6 kB/s eta 0:00:27
#    ------ --------------------------------- 1.6/9.4 MB 300.6 kB/s eta 0:00:27
#    ------ --------------------------------- 1.6/9.4 MB 300.6 kB/s eta 0:00:27
#    ------- -------------------------------- 1.8/9.4 MB 313.6 kB/s eta 0:00:25
#    ------- -------------------------------- 1.8/9.4 MB 313.6 kB/s eta 0:00:25
#    -------- ------------------------------- 2.1/9.4 MB 338.4 kB/s eta 0:00:22
#    -------- ------------------------------- 2.1/9.4 MB 338.4 kB/s eta 0:00:22
#    ---------- ----------------------------- 2.4/9.4 MB 351.3 kB/s eta 0:00:21
#    ---------- ----------------------------- 2.4/9.4 MB 351.3 kB/s eta 0:00:21
#    ---------- ----------------------------- 2.4/9.4 MB 351.3 kB/s eta 0:00:21
#    ---------- ----------------------------- 2.4/9.4 MB 351.3 kB/s eta 0:00:21
#    ----------- ---------------------------- 2.6/9.4 MB 344.7 kB/s eta 0:00:20
#    ----------- ---------------------------- 2.6/9.4 MB 344.7 kB/s eta 0:00:20
#    ----------- ---------------------------- 2.6/9.4 MB 344.7 kB/s eta 0:00:20
#    ------------ --------------------------- 2.9/9.4 MB 352.4 kB/s eta 0:00:19
#    ------------ --------------------------- 2.9/9.4 MB 352.4 kB/s eta 0:00:19
#    ------------- -------------------------- 3.1/9.4 MB 364.0 kB/s eta 0:00:18
#    ------------- -------------------------- 3.1/9.4 MB 364.0 kB/s eta 0:00:18
#    ------------- -------------------------- 3.1/9.4 MB 364.0 kB/s eta 0:00:18
#    -------------- ------------------------- 3.4/9.4 MB 371.4 kB/s eta 0:00:17
#    -------------- ------------------------- 3.4/9.4 MB 371.4 kB/s eta 0:00:17
#    -------------- ------------------------- 3.4/9.4 MB 371.4 kB/s eta 0:00:17
#    --------------- ------------------------ 3.7/9.4 MB 374.7 kB/s eta 0:00:16
#    --------------- ------------------------ 3.7/9.4 MB 374.7 kB/s eta 0:00:16
#    --------------- ------------------------ 3.7/9.4 MB 374.7 kB/s eta 0:00:16
#    ---------------- ----------------------- 3.9/9.4 MB 378.2 kB/s eta 0:00:15
#    ---------------- ----------------------- 3.9/9.4 MB 378.2 kB/s eta 0:00:15
#    ----------------- ---------------------- 4.2/9.4 MB 388.4 kB/s eta 0:00:14
#    ------------------ --------------------- 4.5/9.4 MB 398.8 kB/s eta 0:00:13
#    ------------------ --------------------- 4.5/9.4 MB 398.8 kB/s eta 0:00:13
#    -------------------- ------------------- 4.7/9.4 MB 412.7 kB/s eta 0:00:12
#    --------------------- ------------------ 5.0/9.4 MB 424.1 kB/s eta 0:00:11
#    ---------------------- ----------------- 5.2/9.4 MB 437.9 kB/s eta 0:00:10
#    ---------------------- ----------------- 5.2/9.4 MB 437.9 kB/s eta 0:00:10
#    ----------------------- ---------------- 5.5/9.4 MB 447.4 kB/s eta 0:00:09
#    ----------------------- ---------------- 5.5/9.4 MB 447.4 kB/s eta 0:00:09
#    ----------------------- ---------------- 5.5/9.4 MB 447.4 kB/s eta 0:00:09
#    ------------------------ --------------- 5.8/9.4 MB 443.2 kB/s eta 0:00:09
#    ------------------------ --------------- 5.8/9.4 MB 443.2 kB/s eta 0:00:09
#    ------------------------ --------------- 5.8/9.4 MB 443.2 kB/s eta 0:00:09
#    ------------------------ --------------- 5.8/9.4 MB 443.2 kB/s eta 0:00:09
#    ------------------------ --------------- 5.8/9.4 MB 443.2 kB/s eta 0:00:09
#    ------------------------ --------------- 5.8/9.4 MB 443.2 kB/s eta 0:00:09
#    ------------------------ --------------- 5.8/9.4 MB 443.2 kB/s eta 0:00:09
#    ------------------------- -------------- 6.0/9.4 MB 417.0 kB/s eta 0:00:09
#    ------------------------- -------------- 6.0/9.4 MB 417.0 kB/s eta 0:00:09
#    -------------------------- ------------- 6.3/9.4 MB 421.2 kB/s eta 0:00:08
#    -------------------------- ------------- 6.3/9.4 MB 421.2 kB/s eta 0:00:08
#    --------------------------- ------------ 6.6/9.4 MB 430.2 kB/s eta 0:00:07
#    --------------------------- ------------ 6.6/9.4 MB 430.2 kB/s eta 0:00:07
#    ---------------------------- ----------- 6.8/9.4 MB 434.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.8/9.4 MB 434.2 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.4 MB 437.1 kB/s eta 0:00:06
#    ------------------------------- -------- 7.3/9.4 MB 445.9 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.4 MB 445.9 kB/s eta 0:00:05
#    -------------------------------- ------- 7.6/9.4 MB 452.1 kB/s eta 0:00:05
#    -------------------------------- ------- 7.6/9.4 MB 452.1 kB/s eta 0:00:05
#    -------------------------------- ------- 7.6/9.4 MB 452.1 kB/s eta 0:00:05
#    --------------------------------- ------ 7.9/9.4 MB 452.2 kB/s eta 0:00:04
#    --------------------------------- ------ 7.9/9.4 MB 452.2 kB/s eta 0:00:04
#    ---------------------------------- ----- 8.1/9.4 MB 452.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.1/9.4 MB 452.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.1/9.4 MB 452.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.4/9.4 MB 451.8 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.4/9.4 MB 451.8 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.4/9.4 MB 451.8 kB/s eta 0:00:03
#    ------------------------------------ --- 8.7/9.4 MB 453.4 kB/s eta 0:00:02
#    ------------------------------------- -- 8.9/9.4 MB 459.1 kB/s eta 0:00:02
#    ------------------------------------- -- 8.9/9.4 MB 459.1 kB/s eta 0:00:02
#    ------------------------------------- -- 8.9/9.4 MB 459.1 kB/s eta 0:00:02
#    ------------------------------------- -- 8.9/9.4 MB 459.1 kB/s eta 0:00:02
#    -------------------------------------- - 9.2/9.4 MB 451.6 kB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 457.4 kB/s eta 0:00:00
# Downloading certifi-2025.7.14-py3-none-any.whl (162 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached trio-0.30.0-py3-none-any.whl (499 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: wsproto, urllib3, typing-extensions, rsa, oauthlib, httplib2, dnspython, chromedriver-autoinstaller, certifi, attrs, outcome, oauth2client, google-auth, email-validator, trio, requests-oauthlib, trio-websocket, google-auth-oauthlib, selenium, gspread, jobhunter
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.4.26
#     Uninstalling certifi-2025.4.26:
#       Successfully uninstalled certifi-2025.4.26
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-25.3.0 certifi-2025.7.14 chromedriver-autoinstaller-0.6.4 dnspython-2.7.0 email-validator-2.2.0 google-auth-2.40.3 google-auth-oauthlib-1.2.2 gspread-6.2.1 httplib2-0.22.0 jobhunter-0.0.2 oauth2client-4.1.3 oauthlib-3.3.1 outcome-1.3.0.post0 requests-oauthlib-2.0.0 rsa-4.9.1 selenium-4.34.2 trio-0.30.0 trio-websocket-0.12.2 typing-extensions-4.14.1 urllib3-2.5.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
